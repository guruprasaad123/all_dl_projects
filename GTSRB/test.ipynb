# %%
import numpy as np
import pandas as pd
from PIL import Image
import os
import torch
import torchvision.transforms as transforms
from torch.autograd import Variable
import torchvision.utils as vutils

from model import *
from test import *

# %%
input_image = os.path.join( 'test' , 'stop-sign.jpg' )

# %%
image = Image.open(input_image)
image = image.convert("RGB")
image
# Out:
# <PIL.Image.Image image mode=RGB size=1200x797 at 0x7FB0781A9550>

# %%
load_size = 32

h = image.size[0]
w = image.size[1]
ratio = h * 1.0 / w
if ratio > 1:
    h = load_size
    w = int(h*1.0 / ratio)
else:
    w = load_size
    h = int(w * ratio)
image = image.resize((28, 28), Image.BICUBIC)
image
# Out:
# <PIL.Image.Image image mode=RGB size=28x28 at 0x7FB0781AFC90>

# %%
model = get_model()

result = predict( model , input_image )
# Out:
#  [*] Model Restored from 40 Epoch
#
# tensor([35], device='cuda:0')
# /mnt/e/workspace/submissions/Orbuculum/model.py:89: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.log_softmax(x)
